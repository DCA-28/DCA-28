# %% [markdown]
# <a href="https://colab.research.google.com/github/DCA-28/DCA-28/blob/dev_branch/Trabalho_1_filas_e_ru%C3%ADnas_do_apostador.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Trabalho 1
# ##Filas e Ruína do Apostador
# ##Modelagem e Avaliação de Desempenho
#
# ## Entrega Preliminar
#
# ### Alunos:
# Daniel Corcino de Albuquerque - DRE: 118188457
#
# Letícia Freire Carvalho de Sousa - DRE: 118025324
#
# Lucas Favilla Ferreira Alves da Silva - DRE: 119156518
#
# Roberto Leonie Ferreira Moreira - DRE: 116062192

# %% [markdown]
# ## Simulação
#
# Fizemos uma simulação em que passamos como parâmetros:
#
# $\lambda$ - taxa da variável exponencial que modela o tempo entre as chegadas dos clientes
#
# $\mu$ - taxa da variável exponencial que modela a vida residual dos clientes
#
# `LIM_TIME` - Tempo limite que passamos aceitando novos clientes na fila de espera
#
# Após passarmos do tempo limite terminamos a simulação com os clientes que já estavam na fila de espera.
#
#
# Estamos computando os ciclos de vida do servidor (do nascimento a morte) bem como seus ciclos ociosos.
#
# ### Métricas
#
# Para entrega preliminar computamos:
#
#   $E(N)$ = valor esperado do número de clientes no sistema, a cada momento
#
#   $E(Nq)$ = número de clientes na fila de espera, a cada chegada de novo cliente
#
#   $E(X)$ = valor esperado do tempo de serviço prestado a cada cliente
#
#   $E(W)$ = valor esperado do tempo na fila de espera de cada cliente
#
#   $E(T)$ = valor esperado do tempo de cada cliente no sistema

# %%
import numpy as np
import random
import copy
import time
from queue import PriorityQueue

# A simulacao em si
def simulation(LAMBDA, MU, LIM_TIME, QUEUE_MAX_SIZE = -1, VERBOSE = 0):

  # Medidas interessantes a serem analisadas
  class Measures:
    def __init__(self):
      #variaveis auxiliares para as medidas
      self.TotalClients = 0 # número total de clientes que passaram pelo sistema
      self.sum_Nq = 0 #  somatorio do número de clientes na fila de espera a cada vez que um cliente chega
      self.N = 0 # total medio de clientes no sistema a cada momento
      self.T = 0 # somatorio do tempo total gasto no sistema por cada cliente
      self.W = 0 # somatorio do tempo total gasto na fila de espera por cada cliente
      self.X = 0 # somatorio do tempo total gasto em serviço por cada cliente

      self.count_idle_cycles = 0 # numero de ciclos ociosos
      self.count_birth_and_death_processes = 0 # numero de ciclos de vida e morte
      self.sum_idle_cycles_time = 0 # somatorio da duração de cada ciclo ocioso
      self.sum_birth_and_death_processes_time = 0 # somatorio da duração de cada ciclo de vida e morte
      self.sum_time = 0 # tempo total de simulação

    # valor esperado do número de clientes no sistema, a cada momento
    def Expected_Value_N(self):
      return self.N / (self.sum_time)

    # valor esperado do número de clientes na fila de espera, a cada chegada de novo cliente
    def Expected_Value_Nq(self):
      return self.sum_Nq / self.TotalClients

    # valor esperado da porcentagem do tempo em que o sistema está ativo
    def Expected_Value_Rho(self):
      return self.sum_birth_and_death_processes_time / (self.sum_time)

    # valor esperado do tempo de serviço prestado a cada cliente
    def Expected_Value_X(self):
      return self.X / self.TotalClients

    # valor esperado do tempo na fila de espera de cada cliente
    def Expected_Value_W(self):
      return self.W / self.TotalClients

    # valor esperado do tempo de cada cliente no sistema
    def Expected_Value_T(self):
      return self.T / self.TotalClients

  # classe que modela os eventos de chegada e saída de cada cliente no sistema
  # id -- id do cliente -- incremental a partir de 1
  # event_type -- tipo do evento ("A" - chegada, "D" - saída)
  # arrival_time -- momento da chegada no sistema
  # departure_time -- momento de saída do sistema
  # service_start -- momento em que começa a ser serviço
  # time -- momento atual, pode ser igual a arrival_time ou departure_time, a depender
  #         de qual evento está sendo modelado

  class Event:
    def __init__(self, event_type, time, id):
      self.event_type = event_type
      self.time = time
      self.service_start = -1
      if(event_type == 'A'):
        self.arrival_time = self.time
        self.departure_time = -1
      else:
        self.departure_time = self.time
      self.id = id

    # para imprimir de forma expressiva os dados do cliente
    def __str__(self):
      if(self.event_type == "A"):
        return str(self.id) + "\t|\t"+str(f"{self.arrival_time:.3f}").format()+ "\t|"
      return str(self.id) + "\t|\t" + str(f"{self.arrival_time:.3f}") + "\t|\t"
      + str(f"{self.service_start:.3f}") + "\t|\t" + str(f"{self.departure_time:.3f}") + "\t|"

    # comparador, utilizado para sabermos que evento vem primeiro
    # em caso de empate damos prioridade para a saída do sistema
    def __lt__(self, other):
      if(self.time<other.time):
          return True
      if(self.time>other.time):
          return False
      else:
          return (self.event_type == 'D')

  # o tempo de vida residual é modelado por uma variavel aleatória exponencial com taxa MU
  def residual_life():
    return random.expovariate(MU)

  # o momento da proxima chegada é modelado pela soma de variaveis aleatórias exponenciais iid com taxa LAMBDA
  ARRIVAL_TIME = 0
  def next_arrival():
    return ARRIVAL_TIME + random.expovariate(LAMBDA)

  # classe para modelar o sistema
  # waiting_queue -- lista que representa a fila de espera (células são do tipo Event)
  # server -- variável do tipo Event que representa o cliente que está sendo servido
  class System:
    def __init__(self, queue_max_size = -1):
      self.waiting_queue = []
      self.server = None
      self.queue_max_size = queue_max_size

    # cliente e entra na lista de espera
    def arrival(self, e):
      if(self.queue_max_size == -1 or self.waiting_queue_size() < self.queue_max_size - 1):
        self.waiting_queue.append(e)

    # cliente que está sendo servido sai do sistema
    # garantidamente só é chamado se o sistema estava ocupado
    def departure(self):
      server = copy.deepcopy(self.server)
      self.server = None
      return server

    # o próximo cliente sai da fila de espera e é servido
    def next(self, T):
      if(self.busy() or not(self.waiting_queue)):
        return None
      self.server = self.waiting_queue.pop(0)
      x = residual_life()
      measures.X += x
      self.server.departure_time = T + x
      self.server.time = self.server.departure_time
      return self.server

    # verifica se o sistema está ocupado
    def busy(self):
      return not(self.server == None)

    # tamanho da fila de espera
    def waiting_queue_size(self):
      return len(self.waiting_queue)

    # tamanho da fila (fila de espera + servidor)
    def full_queue_size(self):
      s = len(self.waiting_queue)
      if(self.busy()):
        s += 1
      return s

    # para imprimir de forma expressiva os dados dos clientes na fila
    # imprimimos os dados de no máximo 5 clientes para não poluir a simulação
    def __str__(self):
      ans = "\tServidor: \n"
      ans += "\033[1m"+"\tid\t|\tchegada\t|\tservidor|\tsaída\t|\n"+"\033[0m"
      ans += "\t" + str(self.server) + "\n"


      ans += "\n \tFila de Espera: ("+ str(self.waiting_queue_size())+ ") \n"

      ans += "\033[1m"+"\tid\t|\tchegada\t|\n"+"\033[0m"

      lim = 5
      for w in self.waiting_queue:
        ans += "\t" + str(w) + " \n"
        lim -= 1
        if(lim == 0):
          ans += "\t...\n"
          break
      ans += "---------------------------------------\n"
      return ans


  # variáveis principais
  system = System(QUEUE_MAX_SIZE)
  measures = Measures()
  eventQueue = PriorityQueue()

  id = 0 # id do próximo cliente que chegará

  ARRIVAL_TIME = 0
  # evento de chegada do próximo cliente
  # é inicializado fora do laço principal para que a simulção comece com um cliente no sistema
  eventQueue.put(Event('A', ARRIVAL_TIME, id))

  T = -1 # tempo atual
  birth = -1 # tempo do último nascimento, -1 se ocioso
  death = -1 # tempo da última morte, -1 se é o primeiro ciclo de vida e morte
  count_clients = 0 # número total de clientes que passaram pelo sistema no ciclo de vida e morte atual

  # laço principal da simulação
  # Quando a simulação chega ao tempo limite paramos a simulação
  while(T < LIM_TIME):
    # evento atual, pode ser de chegada ou de saída
    current_event = eventQueue.get()

    # se o evento atual é de chegada
    if(current_event.event_type == "A"):
      if(VERBOSE > 1):
        print("Arrival event: ")

      id += 1

      ARRIVAL_TIME = next_arrival()
      next_arrival_event = Event('A', ARRIVAL_TIME, id)
      eventQueue.put(next_arrival_event)

    # se o evento atual é de partida
    else:
      if(VERBOSE > 1):
        print("Departure event: ")

      # atualizamos a métrica do tempo total do cliente no sistema
      measures.T += current_event.departure_time - current_event.arrival_time


    if(VERBOSE > 1):
      print("\033[1m"+"id\t|\tchegada\t|\tservidor|\tsaída\t|\n"+"\033[0m")
      print(current_event)

    # atualizamos tempo atual da simulação
    last_T = T
    T = current_event.time

    if(VERBOSE > 1):
      print(f"\nCurrent event time: {T:.3f}\n")

    # se o evento atual é de chegada e vai ser aceito
    if(current_event.event_type == 'A' and not(system.waiting_queue_size() == system.queue_max_size)):
      # atualizamos a métrica do número de clientes na fila de espera no momento de chegada do cliente
      measures.sum_Nq += system.waiting_queue_size()

      # numero total de clientes que passaram pelo sistema
      measures.TotalClients += 1

      count_clients += 1
      if(birth == -1):
        birth = T

        # se estamos começando novo ciclo de vida e morte
        if(not(death == -1)):
          # atualizamos várias métricas:

          # somatório do número de clientes no sistema a cada momento
          measures.N += system.full_queue_size() * (T - last_T)

          # número de ciclos ociosos
          measures.count_idle_cycles += 1

          # somatorio da duração de cada ciclo ocioso
          measures.sum_idle_cycles_time += birth - death

          # tempo total de simulação
          measures.sum_time += birth - death

          if(VERBOSE > 1):
            print(f"servidor ocioso de {death:.3f} ate {birth:.3f}")
      system.arrival(current_event)

    # se o evento atual é de saída
    else:
      # somatório do número de clientes no sistema a cada momento
      measures.N += system.full_queue_size() * (T - last_T)

      # cliente termina de ser servido
      system.departure()

    serving = system.next(T)
    # se um cliente começou a ser servido neste momento
    if(serving):
      # somatório do tempo que cada cliente passa na fila de espera
      measures.W += T - serving.arrival_time

      # gerando o evento de saída do cliente do sistema
      serving.service_start = T
      serving.event_type = 'D'
      next_departure_event = serving
      eventQueue.put(next_departure_event)

    # se o sistema está ocioso
    if(not(system.busy())):
      death = T
      # atualizamos várias métricas:

      # número de ciclos de vida e morte
      measures.count_birth_and_death_processes += 1

      # somatorio da duração de cada ciclo de vida e morte
      measures.sum_birth_and_death_processes_time += death - birth

      # tempo total de simulação
      measures.sum_time += death - birth

      if(VERBOSE > 1):
        print(f"servidor ficou ativo de {birth:.3f} ate {death:.3f} e atendeu {count_clients} clientes")
      count_clients = 0
      birth = -1

      if(VERBOSE > 1):
        print("")
    if(VERBOSE > 1):
      print(system)

  if(VERBOSE > 0):
    print("Métricas obtidas:")
    print(f"E[T] =  {measures.Expected_Value_T():.3f}")
    print(f"E[W] =  {measures.Expected_Value_W():.3f}")
    print(f"E[X] =  {measures.Expected_Value_X():.3f}")
    print("")
    print(f"E[N] =  {measures.Expected_Value_N():.3f}")
    print(f"E[Nq] =  {measures.Expected_Value_Nq():.3f}")
    print(f"E[Rho] =  {measures.Expected_Value_Rho():.3f}")

  return measures

# %% [markdown]
# ## Resultado das simulações

# %%
def experiment(LAMBDA, MU, QUEUE_MAX_SIZE = -1, MAX_ITERATIONS = 10):
  LIM_TIME = 100000
  T = 1.96

  averages = {"T": 0.0, "W": 0.0, "X":0.0, "N":0.0, "Nq": 0.0, "Rho": 0.0}
  variances = {"T": 0.0, "W": 0.0, "X":0.0, "N":0.0, "Nq": 0.0, "Rho": 0.0}
  std_dev = {"T": 0.0, "W": 0.0, "X":0.0, "N":0.0, "Nq": 0.0, "Rho": 0.0}
  results = {"T": [], "W": [], "X":[], "N":[], "Nq":[], "Rho": []}
  confidence_interval = {"T": [], "W": [], "X":[], "N":[], "Nq":[], "Rho": []}


  def calc_average(s):
    n = len(s)
    total = 0
    for x in s:
      total += x
    return total / n

  def calc_variance(s, average):
    n = len(s)
    if(n == 1):
      return 0.0
    total = 0
    for x in s:
      total += (x - average) ** 2
    return total / (n - 1)


  def calc_confidence_interval(t):
    return [averages[key] - t * std_dev[key] / ((it+1)**0.5), averages[key] + t * std_dev[key] / ((it+1)**0.5)]

  for it in range(MAX_ITERATIONS):
    current = simulation(LAMBDA, MU, LIM_TIME, QUEUE_MAX_SIZE)
    results["T"].append(current.Expected_Value_T())
    results["W"].append(current.Expected_Value_W())
    results["X"].append(current.Expected_Value_X())
    results["N"].append(current.Expected_Value_N())
    results["Nq"].append(current.Expected_Value_Nq())
    results["Rho"].append(current.Expected_Value_Rho())

    print(f"Simulacao {it+1}")


    for key, value in results.items():
      averages[key] = calc_average(value)
      variances[key] = calc_variance(value, averages[key])
      std_dev[key] = variances[key] ** (1/2)
      confidence_interval[key] = calc_confidence_interval(T)
      print(f" {key} média {averages[key]:.3f} variancia {variances[key]:.6f} desvio padrão {std_dev[key]:.6f} intervalo de confiança: ({confidence_interval[key][0]:.3f}, {confidence_interval[key][1]:.3f})")

    print()

# %% [markdown]
# #Resultado dos experimentos

# %% [markdown]
# ## Filas infinitas
#
# Abaixo apresentamos o resultado dos experimentos, cada um com 20 simulações com os valores sugeridos no enunciado e LIM_TIME = 1000000.

# %%
experiment(1, 2)

# %%
experiment(2, 4)
# Out:
# Simulacao 1
#  T média 0.502 variancia 0.000000 desvio padrão 0.000000 intervalo de confiança: (0.502, 0.502)
#  W média 0.252 variancia 0.000000 desvio padrão 0.000000 intervalo de confiança: (0.252, 0.252)
#  X média 0.251 variancia 0.000000 desvio padrão 0.000000 intervalo de confiança: (0.251, 0.251)
#  N média 0.667 variancia 0.000000 desvio padrão 0.000000 intervalo de confiança: (0.667, 0.667)
#  Nq média 0.501 variancia 0.000000 desvio padrão 0.000000 intervalo de confiança: (0.501, 0.501)
#  Rho média 0.500 variancia 0.000000 desvio padrão 0.000000 intervalo de confiança: (0.500, 0.500)
#
# Simulacao 2
#  T média 0.501 variancia 0.000002 desvio padrão 0.001310 intervalo de confiança: (0.499, 0.503)
#  W média 0.251 variancia 0.000001 desvio padrão 0.000792 intervalo de confiança: (0.250, 0.252)
#  X média 0.250 variancia 0.000000 desvio padrão 0.000522 intervalo de confiança: (0.249, 0.251)
#  N média 0.668 variancia 0.000000 desvio padrão 0.000521 intervalo de confiança: (0.667, 0.668)
#  Nq média 0.502 variancia 0.000002 desvio padrão 0.001299 intervalo de confiança: (0.501, 0.504)
#  Rho média 0.501 variancia 0.000002 desvio padrão 0.001578 intervalo de confiança: (0.498, 0.503)
#
# Simulacao 3
#  T média 0.501 variancia 0.000001 desvio padrão 0.000932 intervalo de confiança: (0.500, 0.502)
#  W média 0.251 variancia 0.000000 desvio padrão 0.000566 intervalo de confiança: (0.250, 0.252)
#  X média 0.250 variancia 0.000000 desvio padrão 0.000413 intervalo de confiança: (0.250, 0.251)
#  N média 0.668 variancia 0.000000 desvio padrão 0.000504 intervalo de confiança: (0.667, 0.669)
#  Nq média 0.503 variancia 0.000001 desvio padrão 0.001000 intervalo de confiança: (0.501, 0.504)
#  Rho média 0.501 variancia 0.000002 desvio padrão 0.001355 intervalo de confiança: (0.500, 0.503)
#
# Simulacao 4
#  T média 0.503 variancia 0.000015 desvio padrão 0.003837 intervalo de confiança: (0.499, 0.507)
#  W média 0.253 variancia 0.000012 desvio padrão 0.003467 intervalo de confiança: (0.249, 0.256)
#  X média 0.250 variancia 0.000000 desvio padrão 0.000468 intervalo de confiança: (0.250, 0.251)
#  N média 0.671 variancia 0.000026 desvio padrão 0.005090 intervalo de confiança: (0.666, 0.675)
#  Nq média 0.506 variancia 0.000051 desvio padrão 0.007153 intervalo de confiança: (0.499, 0.513)
#  Rho média 0.502 variancia 0.000002 desvio padrão 0.001411 intervalo de confiança: (0.500, 0.503)
#
# Simulacao 5
#  T média 0.502 variancia 0.000019 desvio padrão 0.004353 intervalo de confiança: (0.498, 0.506)
#  W média 0.252 variancia 0.000016 desvio padrão 0.003961 intervalo de confiança: (0.248, 0.255)
#  X média 0.250 variancia 0.000000 desvio padrão 0.000465 intervalo de confiança: (0.250, 0.251)
#  N média 0.669 variancia 0.000034 desvio padrão 0.005848 intervalo de confiança: (0.664, 0.674)
#  Nq média 0.503 variancia 0.000104 desvio padrão 0.010219 intervalo de confiança: (0.494, 0.511)
#  Rho média 0.501 variancia 0.000003 desvio padrão 0.001751 intervalo de confiança: (0.499, 0.502)
#
# Simulacao 6
#  T média 0.502 variancia 0.000015 desvio padrão 0.003905 intervalo de confiança: (0.499, 0.505)
#  W média 0.251 variancia 0.000013 desvio padrão 0.003555 intervalo de confiança: (0.249, 0.254)
#  X média 0.250 variancia 0.000000 desvio padrão 0.000416 intervalo de confiança: (0.250, 0.251)
#  N média 0.668 variancia 0.000030 desvio padrão 0.005520 intervalo de confiança: (0.664, 0.672)
#  Nq média 0.503 variancia 0.000084 desvio padrão 0.009175 intervalo de confiança: (0.496, 0.510)
#  Rho média 0.501 variancia 0.000003 desvio padrão 0.001648 intervalo de confiança: (0.499, 0.502)
#
# Simulacao 7
#  T média 0.502 variancia 0.000013 desvio padrão 0.003569 intervalo de confiança: (0.499, 0.504)
#  W média 0.251 variancia 0.000011 desvio padrão 0.003246 intervalo de confiança: (0.249, 0.254)
#  X média 0.250 variancia 0.000000 desvio padrão 0.000451 intervalo de confiança: (0.250, 0.251)
#  N média 0.668 variancia 0.000026 desvio padrão 0.005144 intervalo de confiança: (0.664, 0.671)
#  Nq média 0.503 variancia 0.000072 desvio padrão 0.008495 intervalo de confiança: (0.497, 0.510)
#  Rho média 0.500 variancia 0.000003 desvio padrão 0.001726 intervalo de confiança: (0.499, 0.502)
#
# Simulacao 8
#  T média 0.502 variancia 0.000011 desvio padrão 0.003375 intervalo de confiança: (0.499, 0.504)
#  W média 0.251 variancia 0.000010 desvio padrão 0.003104 intervalo de confiança: (0.249, 0.253)
#  X média 0.250 variancia 0.000000 desvio padrão 0.000428 intervalo de confiança: (0.250, 0.251)
#  N média 0.667 variancia 0.000023 desvio padrão 0.004813 intervalo de confiança: (0.664, 0.671)
#  Nq média 0.503 variancia 0.000067 desvio padrão 0.008162 intervalo de confiança: (0.497, 0.508)
#  Rho média 0.500 variancia 0.000003 desvio padrão 0.001598 intervalo de confiança: (0.499, 0.502)
#
# Simulacao 9
#  T média 0.501 variancia 0.000010 desvio padrão 0.003166 intervalo de confiança: (0.499, 0.504)
#  W média 0.251 variancia 0.000008 desvio padrão 0.002904 intervalo de confiança: (0.249, 0.253)
#  X média 0.250 variancia 0.000000 desvio padrão 0.000486 intervalo de confiança: (0.250, 0.251)
#  N média 0.668 variancia 0.000021 desvio padrão 0.004574 intervalo de confiança: (0.665, 0.671)
#  Nq média 0.503 variancia 0.000058 desvio padrão 0.007637 intervalo de confiança: (0.498, 0.508)
#  Rho média 0.500 variancia 0.000002 desvio padrão 0.001522 intervalo de confiança: (0.499, 0.501)
#
# Simulacao 10
#  T média 0.501 variancia 0.000013 desvio padrão 0.003562 intervalo de confiança: (0.499, 0.503)
#  W média 0.251 variancia 0.000010 desvio padrão 0.003186 intervalo de confiança: (0.249, 0.253)
#  X média 0.250 variancia 0.000000 desvio padrão 0.000556 intervalo de confiança: (0.250, 0.250)
#  N média 0.667 variancia 0.000022 desvio padrão 0.004722 intervalo de confiança: (0.664, 0.670)
#  Nq média 0.502 variancia 0.000060 desvio padrão 0.007777 intervalo de confiança: (0.497, 0.507)
#  Rho média 0.500 variancia 0.000002 desvio padrão 0.001474 intervalo de confiança: (0.499, 0.501)

# %%
experiment(1.05, 1)
# Out:
# Simulacao 1
#  T média 2621.767 variancia 0.000000 desvio padrão 0.000000 intervalo de confiança: (2621.767, 2621.767)
#  W média 2620.870 variancia 0.000000 desvio padrão 0.000000 intervalo de confiança: (2620.870, 2620.870)
#  X média 0.950 variancia 0.000000 desvio padrão 0.000000 intervalo de confiança: (0.950, 0.950)
#  N média 17778850.766 variancia 0.000000 desvio padrão 0.000000 intervalo de confiança: (17778850.766, 17778850.766)
#  Nq média 2917.053 variancia 0.000000 desvio padrão 0.000000 intervalo de confiança: (2917.053, 2917.053)
#  Rho média 0.342 variancia 0.000000 desvio padrão 0.000000 intervalo de confiança: (0.342, 0.342)
#
# Simulacao 2
#  T média 2423.809 variancia 78374.044349 desvio padrão 279.953647 intervalo de confiança: (2035.813, 2811.805)
#  W média 2422.907 variancia 78378.976346 desvio padrão 279.962455 intervalo de confiança: (2034.899, 2810.915)
#  X média 0.951 variancia 0.000001 desvio padrão 0.001167 intervalo de confiança: (0.950, 0.953)
#  N média 9061033.862 variancia 152000663139224.906250 desvio padrão 12328854.899755 intervalo de confiança: (-8025887.270, 26147954.993)
#  Nq média 2677.975 variancia 114316.796918 desvio padrão 338.107671 intervalo de confiança: (2209.382, 3146.568)
#  Rho média 0.622 variancia 0.156623 desvio padrão 0.395756 intervalo de confiança: (0.074, 1.171)
#
# Simulacao 3
#  T média 2497.088 variancia 55296.450462 desvio padrão 235.151973 intervalo de confiança: (2230.989, 2763.188)
#  W média 2496.187 variancia 55299.632768 desvio padrão 235.158740 intervalo de confiança: (2230.080, 2762.295)
#  X média 0.951 variancia 0.000001 desvio padrão 0.000840 intervalo de confiança: (0.950, 0.952)
#  N média 6217177.879 variancia 100262882114593.531250 desvio padrão 10013135.478690 intervalo de confiança: (-5113751.590, 17548107.349)
#  Nq média 2766.343 variancia 80584.985941 desvio padrão 283.874948 intervalo de confiança: (2445.108, 3087.577)
#  Rho média 0.742 variancia 0.121541 desvio padrão 0.348628 intervalo de confiança: (0.348, 1.137)
#
# Simulacao 4
#  T média 2478.604 variancia 38231.000555 desvio padrão 195.527493 intervalo de confiança: (2286.987, 2670.221)
#  W média 2477.702 variancia 38233.225356 desvio padrão 195.533182 intervalo de confiança: (2286.080, 2669.325)
#  X média 0.951 variancia 0.000000 desvio padrão 0.000687 intervalo de confiança: (0.950, 0.952)
#  N média 4786818.235 variancia 75025636262213.906250 desvio padrão 8661734.021673 intervalo de confiança: (-3701681.107, 13275317.576)
#  Nq média 2741.448 variancia 56202.214498 desvio padrão 237.070062 intervalo de confiança: (2509.120, 2973.777)
#  Rho média 0.782 variancia 0.087247 desvio padrão 0.295376 intervalo de confiança: (0.492, 1.071)
#
# Simulacao 5
#  T média 2430.278 variancia 40350.012217 desvio padrão 200.873125 intervalo de confiança: (2254.205, 2606.352)
#  W média 2429.376 variancia 40351.812735 desvio padrão 200.877606 intervalo de confiança: (2253.299, 2605.453)
#  X média 0.951 variancia 0.000002 desvio padrão 0.001392 intervalo de confiança: (0.949, 0.952)
#  N média 3876678.339 variancia 60411000348134.171875 desvio padrão 7772451.373160 intervalo de confiança: (-2936175.673, 10689532.351)
#  Nq média 2686.351 variancia 57330.196823 desvio padrão 239.437250 intervalo de confiança: (2476.475, 2896.227)
#  Rho média 0.820 variancia 0.072811 desvio padrão 0.269836 intervalo de confiança: (0.583, 1.056)
#
# Simulacao 6
#  T média 2356.300 variancia 65116.497465 desvio padrão 255.179344 intervalo de confiança: (2152.114, 2560.486)
#  W média 2355.396 variancia 65120.319219 desvio padrão 255.186832 intervalo de confiança: (2151.204, 2559.588)
#  X média 0.951 variancia 0.000006 desvio padrão 0.002445 intervalo de confiança: (0.949, 0.953)
#  N média 3259688.550 variancia 50612858672895.492188 desvio padrão 7114271.478718 intervalo de confiança: (-2432914.221, 8952291.322)
#  Nq média 2598.594 variancia 92072.454985 desvio padrão 303.434433 intervalo de confiança: (2355.796, 2841.392)
#  Rho média 0.843 variancia 0.061411 desvio padrão 0.247812 intervalo de confiança: (0.645, 1.041)
#
# Simulacao 7
#  T média 2329.286 variancia 59372.078568 desvio padrão 243.663864 intervalo de confiança: (2148.778, 2509.795)
#  W média 2328.382 variancia 59375.272041 desvio padrão 243.670417 intervalo de confiança: (2147.868, 2508.895)
#  X média 0.951 variancia 0.000005 desvio padrão 0.002298 intervalo de confiança: (0.949, 0.953)
#  N média 2800151.843 variancia 43655600123649.367188 desvio padrão 6607238.464264 intervalo de confiança: (-2094558.909, 7694862.595)
#  Nq média 2570.027 variancia 82439.211962 desvio padrão 287.122294 intervalo de confiança: (2357.324, 2782.731)
#  Rho média 0.862 variancia 0.053772 desvio padrão 0.231889 intervalo de confiança: (0.690, 1.034)
#
# Simulacao 8
#  T média 2292.135 variancia 61932.441416 desvio padrão 248.862294 intervalo de confiança: (2119.682, 2464.587)
#  W média 2291.228 variancia 61936.005910 desvio padrão 248.869456 intervalo de confiança: (2118.771, 2463.686)
#  X média 0.952 variancia 0.000009 desvio padrão 0.003049 intervalo de confiança: (0.950, 0.954)
#  N média 2499188.989 variancia 38143714936547.562500 desvio padrão 6176059.822941 intervalo de confiança: (-1780602.117, 6778980.095)
#  Nq média 2526.247 variancia 85995.864311 desvio padrão 293.250515 intervalo de confiança: (2323.035, 2729.459)
#  Rho média 0.870 variancia 0.046559 desvio padrão 0.215776 intervalo de confiança: (0.720, 1.019)
#
# Simulacao 9
#  T média 2290.636 variancia 54211.086431 desvio padrão 232.832743 intervalo de confiança: (2138.519, 2442.754)
#  W média 2289.731 variancia 54214.183058 desvio padrão 232.839393 intervalo de confiança: (2137.609, 2441.853)
#  X média 0.951 variancia 0.000012 desvio padrão 0.003441 intervalo de confiança: (0.949, 0.954)
#  N média 2237668.436 variancia 33991287568328.328125 desvio padrão 5830204.762127 intervalo de confiança: (-1571398.676, 6046735.547)
#  Nq média 2529.111 variancia 75320.193127 desvio padrão 274.445246 intervalo de confiança: (2349.807, 2708.415)
#  Rho média 0.883 variancia 0.042346 desvio padrão 0.205783 intervalo de confiança: (0.749, 1.018)
#
# Simulacao 10
#  T média 2294.818 variancia 48362.457028 desvio padrão 219.914659 intervalo de confiança: (2158.513, 2431.122)
#  W média 2293.912 variancia 48365.221626 desvio padrão 219.920944 intervalo de confiança: (2157.604, 2430.221)
#  X média 0.951 variancia 0.000012 desvio padrão 0.003396 intervalo de confiança: (0.949, 0.953)
#  N média 2037900.346 variancia 30613550734448.167969 desvio padrão 5532951.358403 intervalo de confiança: (-1391458.435, 5467259.127)
#  Nq média 2533.415 variancia 67136.563192 desvio padrão 259.107243 intervalo de confiança: (2372.819, 2694.012)
#  Rho média 0.890 variancia 0.038099 desvio padrão 0.195189 intervalo de confiança: (0.769, 1.011)

# %%
experiment(1.10, 1)
# Out:
# Simulacao 1
#  T média 3985.963 variancia 0.000000 desvio padrão 0.000000 intervalo de confiança: (3985.963, 3985.963)
#  W média 3985.135 variancia 0.000000 desvio padrão 0.000000 intervalo de confiança: (3985.135, 3985.135)
#  X média 0.911 variancia 0.000000 desvio padrão 0.000000 intervalo de confiança: (0.911, 0.911)
#  N média 26731581.346 variancia 0.000000 desvio padrão 0.000000 intervalo de confiança: (26731581.346, 26731581.346)
#  Nq média 4834.902 variancia 0.000000 desvio padrão 0.000000 intervalo de confiança: (4834.902, 4834.902)
#  Rho média 0.729 variancia 0.000000 desvio padrão 0.000000 intervalo de confiança: (0.729, 0.729)
#
# Simulacao 2
#  T média 4168.602 variancia 66713.694860 desvio padrão 258.289943 intervalo de confiança: (3810.630, 4526.573)
#  W média 4167.776 variancia 66715.720063 desvio padrão 258.293864 intervalo de confiança: (3809.799, 4525.753)
#  X média 0.910 variancia 0.000001 desvio padrão 0.001154 intervalo de confiança: (0.908, 0.912)
#  N média 16552195.070 variancia 207239809927341.937500 desvio padrão 14395826.128685 intervalo de confiança: (-3399402.032, 36503792.171)
#  Nq média 5050.261 variancia 92759.107847 desvio padrão 304.563799 intervalo de confiança: (4628.157, 5472.365)
#  Rho média 0.665 variancia 0.008289 desvio padrão 0.091044 intervalo de confiança: (0.539, 0.791)
#
# Simulacao 3
#  T média 4177.457 variancia 33592.109439 desvio padrão 183.281503 intervalo de confiança: (3970.055, 4384.860)
#  W média 4176.634 variancia 33593.206366 desvio padrão 183.284496 intervalo de confiança: (3969.228, 4384.039)
#  X média 0.909 variancia 0.000004 desvio padrão 0.001936 intervalo de confiança: (0.907, 0.911)
#  N média 12631692.926 variancia 149730916147069.343750 desvio padrão 12236458.480585 intervalo de confiança: (-1215163.366, 26478549.217)
#  Nq média 5070.501 variancia 47608.494810 desvio padrão 218.193709 intervalo de confiança: (4823.592, 5317.410)
#  Rho média 0.734 variancia 0.018465 desvio padrão 0.135885 intervalo de confiança: (0.580, 0.888)
#
# Simulacao 4
#  T média 4194.825 variancia 23601.275875 desvio padrão 153.627068 intervalo de confiança: (4044.270, 4345.379)
#  W média 4194.000 variancia 23601.914310 desvio padrão 153.629145 intervalo de confiança: (4043.444, 4344.557)
#  X média 0.909 variancia 0.000003 desvio padrão 0.001615 intervalo de confiança: (0.907, 0.910)
#  N média 11956056.296 variancia 101646550183930.453125 desvio padrão 10081991.379878 intervalo de confiança: (2075704.744, 21836407.849)
#  Nq média 5079.521 variancia 32064.470205 desvio padrão 179.065547 intervalo de confiança: (4904.037, 5255.006)
#  Rho média 0.710 variancia 0.014531 desvio padrão 0.120543 intervalo de confiança: (0.592, 0.829)
#
# Simulacao 5
#  T média 4214.200 variancia 19577.980842 desvio padrão 139.921338 intervalo de confiança: (4091.554, 4336.847)
#  W média 4213.376 variancia 19578.586535 desvio padrão 139.923502 intervalo de confiança: (4090.728, 4336.025)
#  X média 0.908 variancia 0.000002 desvio padrão 0.001559 intervalo de confiança: (0.907, 0.910)
#  N média 10555493.630 variancia 86042791557159.000000 desvio padrão 9275925.374708 intervalo de confiança: (2424786.550, 18686200.709)
#  Nq média 5109.207 variancia 28454.507464 desvio padrão 168.684639 intervalo de confiança: (4961.348, 5257.066)
#  Rho média 0.706 variancia 0.011004 desvio padrão 0.104898 intervalo de confiança: (0.614, 0.798)
#
# Simulacao 6
#  T média 4129.304 variancia 58906.356873 desvio padrão 242.706318 intervalo de confiança: (3935.099, 4323.510)
#  W média 4128.478 variancia 58909.183763 desvio padrão 242.712142 intervalo de confiança: (3934.268, 4322.688)
#  X média 0.909 variancia 0.000004 desvio padrão 0.002090 intervalo de confiança: (0.907, 0.911)
#  N média 9929273.580 variancia 71187142549559.765625 desvio padrão 8437247.332487 intervalo de confiança: (3178069.652, 16680477.507)
#  Nq média 4993.807 variancia 102666.520799 desvio padrão 320.416168 intervalo de confiança: (4737.421, 5250.193)
#  Rho média 0.710 variancia 0.008925 desvio padrão 0.094473 intervalo de confiança: (0.635, 0.786)
#
# Simulacao 7
#  T média 4136.636 variancia 49464.887693 desvio padrão 222.407032 intervalo de confiança: (3971.874, 4301.397)
#  W média 4135.810 variancia 49467.312171 desvio padrão 222.412482 intervalo de confiança: (3971.045, 4300.576)
#  X média 0.909 variancia 0.000004 desvio padrão 0.001910 intervalo de confiança: (0.908, 0.910)
#  N média 8952469.707 variancia 66001639427422.257812 desvio padrão 8124139.303792 intervalo de confiança: (2934023.087, 14970916.327)
#  Nq média 5011.055 variancia 87637.950212 desvio padrão 296.037076 intervalo de confiança: (4791.748, 5230.363)
#  Rho média 0.736 variancia 0.012131 desvio padrão 0.110139 intervalo de confiança: (0.655, 0.818)
#
# Simulacao 8
#  T média 4148.823 variancia 43586.770021 desvio padrão 208.774448 intervalo de confiança: (4004.150, 4293.497)
#  W média 4147.999 variancia 43589.043294 desvio padrão 208.779892 intervalo de confiança: (4003.322, 4292.676)
#  X média 0.908 variancia 0.000006 desvio padrão 0.002486 intervalo de confiança: (0.907, 0.910)
#  N média 8359318.991 variancia 59387455971785.382812 desvio padrão 7706325.711504 intervalo de confiança: (3019107.726, 13699530.257)
#  Nq média 5032.397 variancia 78762.057087 desvio padrão 280.645786 intervalo de confiança: (4837.920, 5226.875)
#  Rho média 0.755 variancia 0.013354 desvio padrão 0.115558 intervalo de confiança: (0.675, 0.836)
#
# Simulacao 9
#  T média 4152.655 variancia 38270.524938 desvio padrão 195.628538 intervalo de confiança: (4024.844, 4280.465)
#  W média 4151.830 variancia 38272.498439 desvio padrão 195.633582 intervalo de confiança: (4024.016, 4279.644)
#  X média 0.909 variancia 0.000007 desvio padrão 0.002607 intervalo de confiança: (0.907, 0.911)
#  N média 7781672.649 variancia 54967101649731.593750 desvio padrão 7413980.148998 intervalo de confiança: (2937872.285, 12625473.013)
#  Nq média 5034.422 variancia 68953.684836 desvio padrão 262.590337 intervalo de confiança: (4862.863, 5205.981)
#  Rho média 0.773 variancia 0.014609 desvio padrão 0.120870 intervalo de confiança: (0.694, 0.852)
#
# Simulacao 10
#  T média 4163.050 variancia 35098.923746 desvio padrão 187.347068 intervalo de confiança: (4046.931, 4279.169)
#  W média 4162.225 variancia 35100.655383 desvio padrão 187.351689 intervalo de confiança: (4046.104, 4278.347)
#  X média 0.909 variancia 0.000006 desvio padrão 0.002496 intervalo de confiança: (0.907, 0.910)
#  N média 7212843.370 variancia 52095313392174.992188 desvio padrão 7217708.319971 intervalo de confiança: (2739261.406, 11686425.335)
#  Nq média 5045.886 variancia 62606.576174 desvio padrão 250.213062 intervalo de confiança: (4890.803, 5200.970)
#  Rho média 0.793 variancia 0.016974 desvio padrão 0.130286 intervalo de confiança: (0.713, 0.874)

# %% [markdown]
# ## Filas Finitas
#
# Abaixo apresentamos o resultado dos experimentos, cada um com 5 simulações com os valores sugeridos no enunciado e LIM_TIME = 100000.

# %%
experiment(1.05, 1, 5)
# Out:
# Simulacao 1
#  T média 2.533 variancia 0.000000 desvio padrão 0.000000 intervalo de confiança: (2.533, 2.533)
#  W média 1.719 variancia 0.000000 desvio padrão 0.000000 intervalo de confiança: (1.719, 1.719)
#  X média 0.814 variancia 0.000000 desvio padrão 0.000000 intervalo de confiança: (0.814, 0.814)
#  N média 1.299 variancia 0.000000 desvio padrão 0.000000 intervalo de confiança: (1.299, 1.299)
#  Nq média 1.804 variancia 0.000000 desvio padrão 0.000000 intervalo de confiança: (1.804, 1.804)
#  Rho média 0.857 variancia 0.000000 desvio padrão 0.000000 intervalo de confiança: (0.857, 0.857)
#
# Simulacao 2
#  T média 2.515 variancia 0.000630 desvio padrão 0.025104 intervalo de confiança: (2.480, 2.550)
#  W média 1.703 variancia 0.000473 desvio padrão 0.021753 intervalo de confiança: (1.673, 1.734)
#  X média 0.812 variancia 0.000011 desvio padrão 0.003362 intervalo de confiança: (0.807, 0.816)
#  N média 1.288 variancia 0.000265 desvio padrão 0.016276 intervalo de confiança: (1.265, 1.310)
#  Nq média 1.792 variancia 0.000255 desvio padrão 0.015963 intervalo de confiança: (1.770, 1.814)
#  Rho média 0.853 variancia 0.000033 desvio padrão 0.005766 intervalo de confiança: (0.845, 0.861)
#
# Simulacao 3
#  T média 2.511 variancia 0.000353 desvio padrão 0.018786 intervalo de confiança: (2.490, 2.533)
#  W média 1.700 variancia 0.000275 desvio padrão 0.016589 intervalo de confiança: (1.681, 1.719)
#  X média 0.812 variancia 0.000006 desvio padrão 0.002378 intervalo de confiança: (0.809, 0.814)
#  N média 1.288 variancia 0.000133 desvio padrão 0.011521 intervalo de confiança: (1.275, 1.301)
#  Nq média 1.790 variancia 0.000141 desvio padrão 0.011880 intervalo de confiança: (1.777, 1.804)
#  Rho média 0.853 variancia 0.000017 desvio padrão 0.004123 intervalo de confiança: (0.848, 0.858)
#
# Simulacao 4
#  T média 2.516 variancia 0.000327 desvio padrão 0.018076 intervalo de confiança: (2.499, 2.534)
#  W média 1.704 variancia 0.000249 desvio padrão 0.015787 intervalo de confiança: (1.688, 1.719)
#  X média 0.812 variancia 0.000006 desvio padrão 0.002426 intervalo de confiança: (0.810, 0.815)
#  N média 1.291 variancia 0.000121 desvio padrão 0.011001 intervalo de confiança: (1.280, 1.302)
#  Nq média 1.791 variancia 0.000101 desvio padrão 0.010074 intervalo de confiança: (1.782, 1.801)
#  Rho média 0.853 variancia 0.000012 desvio padrão 0.003498 intervalo de confiança: (0.850, 0.857)
#
# Simulacao 5
#  T média 2.518 variancia 0.000259 desvio padrão 0.016086 intervalo de confiança: (2.504, 2.532)
#  W média 1.705 variancia 0.000189 desvio padrão 0.013757 intervalo de confiança: (1.693, 1.717)
#  X média 0.813 variancia 0.000009 desvio padrão 0.003032 intervalo de confiança: (0.811, 0.816)
#  N média 1.289 variancia 0.000108 desvio padrão 0.010370 intervalo de confiança: (1.280, 1.298)
#  Nq média 1.790 variancia 0.000091 desvio padrão 0.009544 intervalo de confiança: (1.781, 1.798)
#  Rho média 0.853 variancia 0.000011 desvio padrão 0.003317 intervalo de confiança: (0.850, 0.856)
#
# Simulacao 6
#  T média 2.515 variancia 0.000274 desvio padrão 0.016543 intervalo de confiança: (2.501, 2.528)
#  W média 1.702 variancia 0.000190 desvio padrão 0.013785 intervalo de confiança: (1.691, 1.713)
#  X média 0.813 variancia 0.000011 desvio padrão 0.003339 intervalo de confiança: (0.810, 0.815)
#  N média 1.289 variancia 0.000088 desvio padrão 0.009407 intervalo de confiança: (1.281, 1.296)
#  Nq média 1.788 variancia 0.000089 desvio padrão 0.009457 intervalo de confiança: (1.781, 1.796)
#  Rho média 0.852 variancia 0.000011 desvio padrão 0.003258 intervalo de confiança: (0.850, 0.855)
#
# Simulacao 7
#  T média 2.514 variancia 0.000232 desvio padrão 0.015216 intervalo de confiança: (2.503, 2.525)
#  W média 1.701 variancia 0.000166 desvio padrão 0.012884 intervalo de confiança: (1.691, 1.711)
#  X média 0.813 variancia 0.000010 desvio padrão 0.003179 intervalo de confiança: (0.811, 0.815)
#  N média 1.288 variancia 0.000076 desvio padrão 0.008723 intervalo de confiança: (1.282, 1.294)
#  Nq média 1.785 variancia 0.000141 desvio padrão 0.011876 intervalo de confiança: (1.776, 1.794)
#  Rho média 0.852 variancia 0.000009 desvio padrão 0.003049 intervalo de confiança: (0.850, 0.854)
#
# Simulacao 8
#  T média 2.514 variancia 0.000200 desvio padrão 0.014127 intervalo de confiança: (2.504, 2.524)
#  W média 1.701 variancia 0.000143 desvio padrão 0.011947 intervalo de confiança: (1.692, 1.709)
#  X média 0.814 variancia 0.000012 desvio padrão 0.003414 intervalo de confiança: (0.811, 0.816)
#  N média 1.287 variancia 0.000073 desvio padrão 0.008550 intervalo de confiança: (1.281, 1.293)
#  Nq média 1.784 variancia 0.000124 desvio padrão 0.011139 intervalo de confiança: (1.777, 1.792)
#  Rho média 0.852 variancia 0.000008 desvio padrão 0.002830 intervalo de confiança: (0.850, 0.854)
#
# Simulacao 9
#  T média 2.514 variancia 0.000175 desvio padrão 0.013223 intervalo de confiança: (2.506, 2.523)
#  W média 1.701 variancia 0.000126 desvio padrão 0.011229 intervalo de confiança: (1.694, 1.708)
#  X média 0.813 variancia 0.000011 desvio padrão 0.003257 intervalo de confiança: (0.811, 0.815)
#  N média 1.287 variancia 0.000066 desvio padrão 0.008093 intervalo de confiança: (1.281, 1.292)
#  Nq média 1.785 variancia 0.000118 desvio padrão 0.010863 intervalo de confiança: (1.778, 1.792)
#  Rho média 0.852 variancia 0.000007 desvio padrão 0.002669 intervalo de confiança: (0.850, 0.854)
#
# Simulacao 10
#  T média 2.513 variancia 0.000168 desvio padrão 0.012980 intervalo de confiança: (2.505, 2.521)
#  W média 1.701 variancia 0.000116 desvio padrão 0.010765 intervalo de confiança: (1.694, 1.707)
#  X média 0.813 variancia 0.000012 desvio padrão 0.003496 intervalo de confiança: (0.811, 0.815)
#  N média 1.287 variancia 0.000058 desvio padrão 0.007631 intervalo de confiança: (1.282, 1.291)
#  Nq média 1.785 variancia 0.000105 desvio padrão 0.010245 intervalo de confiança: (1.779, 1.792)
#  Rho média 0.852 variancia 0.000007 desvio padrão 0.002637 intervalo de confiança: (0.850, 0.853)

# %%
experiment(1.10, 1, 5)
# Out:
# Simulacao 1
#  T média 2.521 variancia 0.000000 desvio padrão 0.000000 intervalo de confiança: (2.521, 2.521)
#  W média 1.728 variancia 0.000000 desvio padrão 0.000000 intervalo de confiança: (1.728, 1.728)
#  X média 0.793 variancia 0.000000 desvio padrão 0.000000 intervalo de confiança: (0.793, 0.793)
#  N média 1.325 variancia 0.000000 desvio padrão 0.000000 intervalo de confiança: (1.325, 1.325)
#  Nq média 1.901 variancia 0.000000 desvio padrão 0.000000 intervalo de confiança: (1.901, 1.901)
#  Rho média 0.873 variancia 0.000000 desvio padrão 0.000000 intervalo de confiança: (0.873, 0.873)
#
# Simulacao 2
#  T média 2.519 variancia 0.000008 desvio padrão 0.002773 intervalo de confiança: (2.515, 2.523)
#  W média 1.728 variancia 0.000000 desvio padrão 0.000601 intervalo de confiança: (1.727, 1.729)
#  X média 0.791 variancia 0.000012 desvio padrão 0.003394 intervalo de confiança: (0.786, 0.795)
#  N média 1.322 variancia 0.000019 desvio padrão 0.004362 intervalo de confiança: (1.316, 1.328)
#  Nq média 1.907 variancia 0.000088 desvio padrão 0.009355 intervalo de confiança: (1.895, 1.920)
#  Rho média 0.872 variancia 0.000004 desvio padrão 0.001902 intervalo de confiança: (0.869, 0.875)
#
# Simulacao 3
#  T média 2.523 variancia 0.000045 desvio padrão 0.006722 intervalo de confiança: (2.515, 2.530)
#  W média 1.732 variancia 0.000038 desvio padrão 0.006201 intervalo de confiança: (1.725, 1.739)
#  X média 0.791 variancia 0.000006 desvio padrão 0.002412 intervalo de confiança: (0.788, 0.793)
#  N média 1.324 variancia 0.000018 desvio padrão 0.004294 intervalo de confiança: (1.319, 1.329)
#  Nq média 1.911 variancia 0.000081 desvio padrão 0.009025 intervalo de confiança: (1.901, 1.921)
#  Rho média 0.872 variancia 0.000002 desvio padrão 0.001401 intervalo de confiança: (0.871, 0.874)
#
# Simulacao 4
#  T média 2.519 variancia 0.000081 desvio padrão 0.009016 intervalo de confiança: (2.510, 2.528)
#  W média 1.728 variancia 0.000078 desvio padrão 0.008836 intervalo de confiança: (1.720, 1.737)
#  X média 0.791 variancia 0.000004 desvio padrão 0.001972 intervalo de confiança: (0.789, 0.793)
#  N média 1.321 variancia 0.000058 desvio padrão 0.007587 intervalo de confiança: (1.313, 1.328)
#  Nq média 1.903 variancia 0.000297 desvio padrão 0.017244 intervalo de confiança: (1.886, 1.920)
#  Rho média 0.871 variancia 0.000010 desvio padrão 0.003223 intervalo de confiança: (0.867, 0.874)
#
# Simulacao 5
#  T média 2.520 variancia 0.000063 desvio padrão 0.007916 intervalo de confiança: (2.513, 2.527)
#  W média 1.729 variancia 0.000061 desvio padrão 0.007842 intervalo de confiança: (1.722, 1.736)
#  X média 0.791 variancia 0.000003 desvio padrão 0.001762 intervalo de confiança: (0.789, 0.792)
#  N média 1.321 variancia 0.000045 desvio padrão 0.006739 intervalo de confiança: (1.315, 1.327)
#  Nq média 1.905 variancia 0.000234 desvio padrão 0.015295 intervalo de confiança: (1.891, 1.918)
#  Rho média 0.871 variancia 0.000008 desvio padrão 0.002822 intervalo de confiança: (0.868, 0.873)
#
# Simulacao 6
#  T média 2.521 variancia 0.000071 desvio padrão 0.008434 intervalo de confiança: (2.515, 2.528)
#  W média 1.731 variancia 0.000066 desvio padrão 0.008101 intervalo de confiança: (1.724, 1.737)
#  X média 0.791 variancia 0.000003 desvio padrão 0.001660 intervalo de confiança: (0.789, 0.792)
#  N média 1.321 variancia 0.000037 desvio padrão 0.006043 intervalo de confiança: (1.316, 1.326)
#  Nq média 1.906 variancia 0.000204 desvio padrão 0.014293 intervalo de confiança: (1.895, 1.918)
#  Rho média 0.871 variancia 0.000006 desvio padrão 0.002526 intervalo de confiança: (0.869, 0.873)
#
# Simulacao 7
#  T média 2.522 variancia 0.000066 desvio padrão 0.008108 intervalo de confiança: (2.516, 2.528)
#  W média 1.732 variancia 0.000064 desvio padrão 0.008017 intervalo de confiança: (1.726, 1.738)
#  X média 0.791 variancia 0.000003 desvio padrão 0.001612 intervalo de confiança: (0.789, 0.792)
#  N média 1.322 variancia 0.000035 desvio padrão 0.005898 intervalo de confiança: (1.317, 1.326)
#  Nq média 1.909 variancia 0.000209 desvio padrão 0.014456 intervalo de confiança: (1.898, 1.919)
#  Rho média 0.871 variancia 0.000005 desvio padrão 0.002317 intervalo de confiança: (0.869, 0.872)
#
# Simulacao 8
#  T média 2.522 variancia 0.000058 desvio padrão 0.007640 intervalo de confiança: (2.517, 2.527)
#  W média 1.732 variancia 0.000056 desvio padrão 0.007462 intervalo de confiança: (1.726, 1.737)
#  X média 0.790 variancia 0.000003 desvio padrão 0.001629 intervalo de confiança: (0.789, 0.792)
#  N média 1.322 variancia 0.000030 desvio padrão 0.005462 intervalo de confiança: (1.318, 1.326)
#  Nq média 1.909 variancia 0.000180 desvio padrão 0.013399 intervalo de confiança: (1.900, 1.918)
#  Rho média 0.871 variancia 0.000005 desvio padrão 0.002201 intervalo de confiança: (0.869, 0.872)
#
# Simulacao 9
#  T média 2.522 variancia 0.000051 desvio padrão 0.007166 intervalo de confiança: (2.517, 2.527)
#  W média 1.731 variancia 0.000049 desvio padrão 0.007005 intervalo de confiança: (1.727, 1.736)
#  X média 0.791 variancia 0.000004 desvio padrão 0.001876 intervalo de confiança: (0.790, 0.792)
#  N média 1.321 variancia 0.000028 desvio padrão 0.005320 intervalo de confiança: (1.318, 1.325)
#  Nq média 1.907 variancia 0.000197 desvio padrão 0.014050 intervalo de confiança: (1.898, 1.916)
#  Rho média 0.870 variancia 0.000006 desvio padrão 0.002458 intervalo de confiança: (0.869, 0.872)
#
# Simulacao 10
#  T média 2.522 variancia 0.000047 desvio padrão 0.006865 intervalo de confiança: (2.518, 2.527)
#  W média 1.732 variancia 0.000045 desvio padrão 0.006714 intervalo de confiança: (1.728, 1.736)
#  X média 0.791 variancia 0.000003 desvio padrão 0.001769 intervalo de confiança: (0.790, 0.792)
#  N média 1.321 variancia 0.000028 desvio padrão 0.005256 intervalo de confiança: (1.318, 1.324)
#  Nq média 1.908 variancia 0.000182 desvio padrão 0.013491 intervalo de confiança: (1.899, 1.916)
#  Rho média 0.870 variancia 0.000005 desvio padrão 0.002336 intervalo de confiança: (0.869, 0.871)

# %% [markdown]
# # Espaço de Teste

# %% [markdown]
# Abaixo temos uma célula em que podemos testar diferentes valores de $\mu$, $\lambda$ e LIM_TIME.
#
# Além disso, há um parâmetro extra booleano VERBOSE.
#
# Quando passamos VERBOSE = 2 nós mostramos cada evento de chegada e saída de clientes do sistema, além dos resultados das métricas calculadas.
#
# Quando passamos VERBOSE = 1 nós mostramos somente resultados das métricas calculadas.
#
#
# Quando passamos VERBOSE = 0 não mostramos nada.

# %%
print("   SIMULAÇÃO   ")
LAMBDA = float(input("Taxa lambda (momentos de chegada) : "))
MU = float(input("Taxa mu (vida residual) : "))
LIM_TIME = float(input("Tempo máximo aceitando novos clientes (s): "))
QUEUE_MAX_SIZE = int(input("Tamanho máximo da fila de espera (-1, se ilimitada)"))
VERBOSE = int(input("Verbose? (0 - Não imprime nada; 1 - Imprime métricas obtidas; 2 - Imprime a simulação dos eventos e métricas obtidas)"))
simulation(LAMBDA, MU, LIM_TIME, QUEUE_MAX_SIZE, VERBOSE)
# Out:
#    SIMULAÇÃO
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-698b7377f20b> in <cell line: 2>()
#       1 print("   SIMULAÇÃO   ")
# ----> 2 LAMBDA = float(input("Taxa lambda (momentos de chegada) : "))
#       3 MU = float(input("Taxa mu (vida residual) : "))
#       4 LIM_TIME = float(input("Tempo máximo aceitando novos clientes (s): "))
#       5 QUEUE_MAX_SIZE = int(input("Tamanho máximo da fila de espera (-1, se ilimitada)"))
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
